# %%
import csv

# %%
f = csv.reader("./analysis_summary.csv", delimiter=',', quotechar='"')

# %%
f

# %%
def transpose_csv_method1():
    """Transpose entire CSV using zip(*data)"""
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='"')
        data = list(reader)  # Read all rows into a list
        transposed = list(zip(*data))  # Transpose: rows become columns
        return transposed

# %%
csv_list = transpose_csv_method1("./analysis_summary.csv")

# %%
next(csv_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 next(csv_list)
#
# TypeError: 'list' object is not an iterator
